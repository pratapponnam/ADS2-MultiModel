# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
#         191.65M 100%  927.78kB/s    0:03:21 (xfr#7896, to-chk=0/7897)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):


    #Complete here
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    image = tf.image.resize(image, [64, 64])

    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

batch_size = 64

posters_train_ds = (list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse the image files
    .batch(batch_size)  # Batch the data before processing
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Apply batch processing
    .cache()  # Cache the dataset
    .shuffle(buffer_size=1000)  # Shuffle for training
    .prefetch(tf.data.AUTOTUNE)  # Prefetch for efficient data loading
)

posters_valid_ds = (list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse the image files
    .batch(batch_size)  # Batch the data before processing
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Apply batch processing
    .cache()  # Cache the dataset
    .prefetch(tf.data.AUTOTUNE)  # Prefetch for efficient data loading
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

overviews_train_ds = list_overviews_train_ds.batch(64).prefetch(tf.data.AUTOTUNE)#Complete here

overviews_valid_ds = list_overviews_valid_ds.batch(64).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE)

encoder.adapt(overviews_train_ds.map(lambda text, label: text))
#Complete here

#Complete here

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

#Complete here

vocab = np.array(encoder.get_vocabulary())
print(vocab[:200])
# Out:
# ['' '[UNK]' 'a' 'the' 'to' 'of' 'and' 'in' 'his' 'is' 'an' 'with' 'her'
#  'for' 'on' 'he' 'who' 'their' 'by' 'from' 'when' 'as' 'that' 'after'
#  'young' 'life' 'they' 'man' 'new' 'at' 'him' 'but' 'are' 'two' 'into'
#  'has' 'she' 'up' 'woman' 'out' 'love' 'family' 'one' 'find' 'must' 'be'
#  'it' 'world' 'friends' 'finds' 'story' 'them' 'school' 'where' 'while'
#  'group' 'about' 'have' 'girl' 'father' 'lives' 'years' 'wife' 'war'
#  'three' 'town' 'city' 'becomes' 'get' 'during' 'home' 'help' 'back' 'all'
#  'boy' 'york' 'himself' 'son' 'against' 'which' 'high' 'gets' 'time'
#  'between' 'only' 'team' 'own' 'american' 'friend' 'falls' 'takes' 'being'
#  'small' 'its' 'murder' 'former' 'down' 'tries' 'police' 'before' 'other'
#  'mother' 'save' 'college' 'death' 'will' 'daughter' 'can' 'become' 'take'
#  'agent' 'was' 'through' 'order' 'this' 'set' 'people' 'old' 'way' 'not'
#  'husband' 'together' 'over' 'off' 'goes' 'couple' 'more' 'meets'
#  'returns' 'mysterious' 'living' 'killer' 'us' 'hes' 'each' 'stop'
#  'relationship' 'go' 'just' 'brother' 'local' 'drug' 'discovers' 'comes'
#  'work' 'men' 'four' 'first' 'best' 'begins' 'been' 'now' 'make' 'job'
#  'day' 'cop' 'past' 'house' 'soon' 'what' 'detective' 'women' 'forced'
#  'evil' 'turns' 'secret' 'movie' 'whose' 'discover' 'trying' 'another'
#  'earth' 'away' 'parents' 'come' 'student' 'married' 'run' 'film' 'than'
#  'star' 'some' 'so' 'or' 'live' 'black' 'most' 'then' 'sent' 'prison'
#  'children' 'around' 'true' 'series' 'last' 'fight' 'try' 'under' 'trip'
#  'there']

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    input_tensor = Input(shape=(64, 64, 3), name='Input')

    x = Conv2D(filters=16, kernel_size=3, strides=2, padding='same', activation='relu', name='Conv0')(input_tensor)
    x = Dropout(0.2, name='Drop1')(x)
    x = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv1')(x)
    x = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv2')(x)
    x = Dropout(0.2, name='Drop2')(x)
    x = MaxPooling2D(pool_size=2, name='Pool1')(x)
    x = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv3')(x)
    x = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv4')(x)
    x = Dropout(0.2, name='Drop3')(x)
    x = MaxPooling2D(pool_size=2, name='Pool2')(x)
    x = Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv5')(x)
    x = Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv6')(x)
    x = Dropout(0.2, name='Drop4')(x)
    x = MaxPooling2D(pool_size=2, name='Pool3')(x)
    x = Flatten(name='Flat')(x)
    x = Dense(units=1024, activation='relu', name='FC1')(x)
    x = Dropout(0.5, name='Drop5')(x)
    x = Dense(units=1024, activation='relu', name='FC2')(x)
    x = Dropout(0.5, name='Drop6')(x)
    output_tensor = Dense(units=25, activation='sigmoid', name='Output')(x)

    model = Model(inputs=input_tensor, outputs=output_tensor)



  #Complete here


    return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.


#Complete here
cnn_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    #Complete here
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
    )

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(input_dim=VOCAB_SIZE, output_dim=256, mask_zero=True)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()


#Complete here
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization                   │ (None, None)                │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 256)           │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, None, 512)           │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

lstm_model.compile(
    #Complete here
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
    )

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    filepath=checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

checkpoint_lstm_callback = ModelCheckpoint(
    filepath=checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    #Complete here
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback]
    )
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - loss: 0.4178 - precision: 0.2574 - recall: 0.2816
# Epoch 1: val_loss improved from inf to 0.33514, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 873ms/step - loss: 0.4166 - precision: 0.2585 - recall: 0.2812 - val_loss: 0.3351 - val_precision: 0.5614 - val_recall: 0.1404 - learning_rate: 1.0000e-04
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - loss: 0.2560 - precision: 0.4893 - recall: 0.2111
# Epoch 2: val_loss improved from 0.33514 to 0.32082, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 66s 822ms/step - loss: 0.2559 - precision: 0.4895 - recall: 0.2112 - val_loss: 0.3208 - val_precision: 0.5560 - val_recall: 0.2936 - learning_rate: 1.0000e-04
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - loss: 0.2461 - precision: 0.5225 - recall: 0.2276
# Epoch 3: val_loss improved from 0.32082 to 0.29952, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 67s 831ms/step - loss: 0.2461 - precision: 0.5226 - recall: 0.2277 - val_loss: 0.2995 - val_precision: 0.5546 - val_recall: 0.2834 - learning_rate: 1.0000e-04
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - loss: 0.2424 - precision: 0.5299 - recall: 0.2489
# Epoch 4: val_loss did not improve from 0.29952
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 806ms/step - loss: 0.2424 - precision: 0.5301 - recall: 0.2490 - val_loss: 0.3039 - val_precision: 0.5627 - val_recall: 0.3481 - learning_rate: 1.0000e-04
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - loss: 0.2380 - precision: 0.5520 - recall: 0.2520
# Epoch 5: val_loss improved from 0.29952 to 0.29358, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 800ms/step - loss: 0.2380 - precision: 0.5521 - recall: 0.2521 - val_loss: 0.2936 - val_precision: 0.5634 - val_recall: 0.3345 - learning_rate: 1.0000e-04
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - loss: 0.2344 - precision: 0.5612 - recall: 0.2633
# Epoch 6: val_loss improved from 0.29358 to 0.28056, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 803ms/step - loss: 0.2344 - precision: 0.5612 - recall: 0.2634 - val_loss: 0.2806 - val_precision: 0.5665 - val_recall: 0.3250 - learning_rate: 1.0000e-04
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 782ms/step - loss: 0.2314 - precision: 0.5713 - recall: 0.2493
# Epoch 7: val_loss improved from 0.28056 to 0.27720, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 66s 833ms/step - loss: 0.2314 - precision: 0.5713 - recall: 0.2494 - val_loss: 0.2772 - val_precision: 0.5682 - val_recall: 0.3425 - learning_rate: 1.0000e-04
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - loss: 0.2332 - precision: 0.5750 - recall: 0.2718
# Epoch 8: val_loss improved from 0.27720 to 0.27699, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 79s 797ms/step - loss: 0.2332 - precision: 0.5749 - recall: 0.2718 - val_loss: 0.2770 - val_precision: 0.5686 - val_recall: 0.3269 - learning_rate: 1.0000e-04
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - loss: 0.2316 - precision: 0.5630 - recall: 0.2637
# Epoch 9: val_loss improved from 0.27699 to 0.27068, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 801ms/step - loss: 0.2317 - precision: 0.5631 - recall: 0.2637 - val_loss: 0.2707 - val_precision: 0.5678 - val_recall: 0.3167 - learning_rate: 1.0000e-04
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.2285 - precision: 0.5857 - recall: 0.2868
# Epoch 10: val_loss improved from 0.27068 to 0.26607, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 802ms/step - loss: 0.2285 - precision: 0.5856 - recall: 0.2866 - val_loss: 0.2661 - val_precision: 0.5766 - val_recall: 0.3180 - learning_rate: 1.0000e-04
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - loss: 0.2299 - precision: 0.5842 - recall: 0.2710
# Epoch 11: val_loss did not improve from 0.26607
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 820ms/step - loss: 0.2298 - precision: 0.5841 - recall: 0.2711 - val_loss: 0.2689 - val_precision: 0.5687 - val_recall: 0.3144 - learning_rate: 9.9005e-05
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - loss: 0.2301 - precision: 0.5806 - recall: 0.2668
# Epoch 12: val_loss improved from 0.26607 to 0.26495, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 66s 830ms/step - loss: 0.2301 - precision: 0.5806 - recall: 0.2669 - val_loss: 0.2650 - val_precision: 0.5822 - val_recall: 0.2923 - learning_rate: 9.8020e-05
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - loss: 0.2272 - precision: 0.5984 - recall: 0.2854
# Epoch 13: val_loss improved from 0.26495 to 0.26123, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 79s 806ms/step - loss: 0.2272 - precision: 0.5983 - recall: 0.2854 - val_loss: 0.2612 - val_precision: 0.5731 - val_recall: 0.2979 - learning_rate: 9.7045e-05
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - loss: 0.2292 - precision: 0.5906 - recall: 0.2776
# Epoch 14: val_loss did not improve from 0.26123
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 793ms/step - loss: 0.2292 - precision: 0.5906 - recall: 0.2776 - val_loss: 0.2612 - val_precision: 0.5989 - val_recall: 0.2840 - learning_rate: 9.6079e-05
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - loss: 0.2272 - precision: 0.5783 - recall: 0.2718
# Epoch 15: val_loss improved from 0.26123 to 0.25746, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 85s 837ms/step - loss: 0.2272 - precision: 0.5784 - recall: 0.2718 - val_loss: 0.2575 - val_precision: 0.6053 - val_recall: 0.2734 - learning_rate: 9.5123e-05
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.2264 - precision: 0.6085 - recall: 0.2804
# Epoch 16: val_loss did not improve from 0.25746
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 799ms/step - loss: 0.2264 - precision: 0.6084 - recall: 0.2804 - val_loss: 0.2587 - val_precision: 0.5732 - val_recall: 0.2830 - learning_rate: 9.4176e-05
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - loss: 0.2256 - precision: 0.6127 - recall: 0.2811
# Epoch 17: val_loss improved from 0.25746 to 0.25636, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 796ms/step - loss: 0.2256 - precision: 0.6126 - recall: 0.2811 - val_loss: 0.2564 - val_precision: 0.5604 - val_recall: 0.2526 - learning_rate: 9.3239e-05
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - loss: 0.2259 - precision: 0.5950 - recall: 0.2721
# Epoch 18: val_loss did not improve from 0.25636
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 83s 803ms/step - loss: 0.2259 - precision: 0.5951 - recall: 0.2722 - val_loss: 0.2590 - val_precision: 0.5655 - val_recall: 0.2579 - learning_rate: 9.2312e-05
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - loss: 0.2246 - precision: 0.6030 - recall: 0.2986
# Epoch 19: val_loss improved from 0.25636 to 0.24921, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 67s 836ms/step - loss: 0.2246 - precision: 0.6031 - recall: 0.2985 - val_loss: 0.2492 - val_precision: 0.6179 - val_recall: 0.2665 - learning_rate: 9.1393e-05
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - loss: 0.2245 - precision: 0.6150 - recall: 0.2789
# Epoch 20: val_loss did not improve from 0.24921
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 831ms/step - loss: 0.2245 - precision: 0.6150 - recall: 0.2790 - val_loss: 0.2515 - val_precision: 0.5762 - val_recall: 0.2559 - learning_rate: 9.0484e-05
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.2245 - precision: 0.6067 - recall: 0.2778
# Epoch 21: val_loss improved from 0.24921 to 0.24880, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 806ms/step - loss: 0.2245 - precision: 0.6068 - recall: 0.2778 - val_loss: 0.2488 - val_precision: 0.5759 - val_recall: 0.2404 - learning_rate: 8.9583e-05
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - loss: 0.2244 - precision: 0.6133 - recall: 0.2828
# Epoch 22: val_loss improved from 0.24880 to 0.24479, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 800ms/step - loss: 0.2244 - precision: 0.6134 - recall: 0.2828 - val_loss: 0.2448 - val_precision: 0.5824 - val_recall: 0.2497 - learning_rate: 8.8692e-05
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - loss: 0.2209 - precision: 0.6198 - recall: 0.2973
# Epoch 23: val_loss did not improve from 0.24479
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 87s 868ms/step - loss: 0.2210 - precision: 0.6198 - recall: 0.2971 - val_loss: 0.2482 - val_precision: 0.6137 - val_recall: 0.2345 - learning_rate: 8.7810e-05
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - loss: 0.2226 - precision: 0.6325 - recall: 0.2780
# Epoch 24: val_loss improved from 0.24479 to 0.24316, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 788ms/step - loss: 0.2226 - precision: 0.6324 - recall: 0.2780 - val_loss: 0.2432 - val_precision: 0.6319 - val_recall: 0.2943 - learning_rate: 8.6936e-05
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - loss: 0.2207 - precision: 0.6344 - recall: 0.2887
# Epoch 25: val_loss improved from 0.24316 to 0.24293, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 797ms/step - loss: 0.2207 - precision: 0.6344 - recall: 0.2886 - val_loss: 0.2429 - val_precision: 0.5607 - val_recall: 0.2318 - learning_rate: 8.6071e-05
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.2206 - precision: 0.6321 - recall: 0.2745
# Epoch 26: val_loss improved from 0.24293 to 0.24164, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 808ms/step - loss: 0.2206 - precision: 0.6322 - recall: 0.2746 - val_loss: 0.2416 - val_precision: 0.5911 - val_recall: 0.2602 - learning_rate: 8.5214e-05
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - loss: 0.2186 - precision: 0.6474 - recall: 0.2815
# Epoch 27: val_loss did not improve from 0.24164
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 86s 864ms/step - loss: 0.2186 - precision: 0.6473 - recall: 0.2815 - val_loss: 0.2429 - val_precision: 0.6000 - val_recall: 0.2774 - learning_rate: 8.4366e-05
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - loss: 0.2190 - precision: 0.6431 - recall: 0.2805
# Epoch 28: val_loss improved from 0.24164 to 0.23629, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 799ms/step - loss: 0.2190 - precision: 0.6431 - recall: 0.2805 - val_loss: 0.2363 - val_precision: 0.5935 - val_recall: 0.2536 - learning_rate: 8.3527e-05
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - loss: 0.2189 - precision: 0.6438 - recall: 0.2760
# Epoch 29: val_loss did not improve from 0.23629
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 795ms/step - loss: 0.2189 - precision: 0.6439 - recall: 0.2760 - val_loss: 0.2403 - val_precision: 0.6088 - val_recall: 0.2652 - learning_rate: 8.2696e-05
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - loss: 0.2176 - precision: 0.6520 - recall: 0.2856
# Epoch 30: val_loss improved from 0.23629 to 0.23569, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 802ms/step - loss: 0.2176 - precision: 0.6520 - recall: 0.2856 - val_loss: 0.2357 - val_precision: 0.6250 - val_recall: 0.2774 - learning_rate: 8.1873e-05
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.2169 - precision: 0.6605 - recall: 0.2880
# Epoch 31: val_loss did not improve from 0.23569
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 800ms/step - loss: 0.2169 - precision: 0.6604 - recall: 0.2880 - val_loss: 0.2364 - val_precision: 0.5947 - val_recall: 0.2394 - learning_rate: 8.1058e-05
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - loss: 0.2159 - precision: 0.6596 - recall: 0.2848
# Epoch 32: val_loss did not improve from 0.23569
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 799ms/step - loss: 0.2159 - precision: 0.6596 - recall: 0.2848 - val_loss: 0.2373 - val_precision: 0.5933 - val_recall: 0.2573 - learning_rate: 8.0252e-05
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - loss: 0.2154 - precision: 0.6587 - recall: 0.2827
# Epoch 33: val_loss improved from 0.23569 to 0.23377, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 806ms/step - loss: 0.2154 - precision: 0.6586 - recall: 0.2827 - val_loss: 0.2338 - val_precision: 0.6225 - val_recall: 0.2609 - learning_rate: 7.9453e-05
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - loss: 0.2145 - precision: 0.6634 - recall: 0.2856
# Epoch 34: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 801ms/step - loss: 0.2145 - precision: 0.6634 - recall: 0.2856 - val_loss: 0.2404 - val_precision: 0.6006 - val_recall: 0.2523 - learning_rate: 7.8663e-05
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - loss: 0.2131 - precision: 0.6566 - recall: 0.2842
# Epoch 35: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 63s 792ms/step - loss: 0.2131 - precision: 0.6567 - recall: 0.2842 - val_loss: 0.2369 - val_precision: 0.5781 - val_recall: 0.2384 - learning_rate: 7.7880e-05
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - loss: 0.2153 - precision: 0.6664 - recall: 0.2807
# Epoch 36: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 798ms/step - loss: 0.2153 - precision: 0.6664 - recall: 0.2808 - val_loss: 0.2363 - val_precision: 0.6153 - val_recall: 0.2731 - learning_rate: 7.7105e-05
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - loss: 0.2123 - precision: 0.6741 - recall: 0.2960
# Epoch 37: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 806ms/step - loss: 0.2123 - precision: 0.6741 - recall: 0.2960 - val_loss: 0.2375 - val_precision: 0.6154 - val_recall: 0.2668 - learning_rate: 7.6338e-05
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - loss: 0.2116 - precision: 0.6746 - recall: 0.2908
# Epoch 38: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 85s 846ms/step - loss: 0.2116 - precision: 0.6746 - recall: 0.2909 - val_loss: 0.2355 - val_precision: 0.6436 - val_recall: 0.2761 - learning_rate: 7.5578e-05
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 789ms/step - loss: 0.2109 - precision: 0.6637 - recall: 0.2939
# Epoch 39: val_loss did not improve from 0.23377
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 841ms/step - loss: 0.2109 - precision: 0.6637 - recall: 0.2939 - val_loss: 0.2415 - val_precision: 0.6152 - val_recall: 0.2566 - learning_rate: 7.4826e-05
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - loss: 0.2099 - precision: 0.6799 - recall: 0.2998
# Epoch 40: val_loss improved from 0.23377 to 0.23318, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 80s 815ms/step - loss: 0.2099 - precision: 0.6798 - recall: 0.2998 - val_loss: 0.2332 - val_precision: 0.6395 - val_recall: 0.2876 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.
lstm_history = lstm_model.fit(

                    #Complete here
                    overviews_train_ds,
                    validation_data=overviews_valid_ds,
                    epochs=20,
                    callbacks=[checkpoint_lstm_callback, lr_callback]
                    )
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.6668 - precision_1: 0.1123 - recall_1: 0.4223
# Epoch 1: val_loss improved from inf to 0.38039, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - loss: 0.6662 - precision_1: 0.1125 - recall_1: 0.4218 - val_loss: 0.3804 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4825 - precision_1: 0.1733 - recall_1: 0.3425
# Epoch 2: val_loss improved from 0.38039 to 0.31326, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.4824 - precision_1: 0.1734 - recall_1: 0.3425 - val_loss: 0.3133 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.4305 - precision_1: 0.1993 - recall_1: 0.3095
# Epoch 3: val_loss improved from 0.31326 to 0.28185, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - loss: 0.4304 - precision_1: 0.1994 - recall_1: 0.3095 - val_loss: 0.2818 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3909 - precision_1: 0.2425 - recall_1: 0.3060
# Epoch 4: val_loss improved from 0.28185 to 0.26440, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.3909 - precision_1: 0.2425 - recall_1: 0.3058 - val_loss: 0.2644 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3631 - precision_1: 0.2710 - recall_1: 0.2876
# Epoch 5: val_loss improved from 0.26440 to 0.25748, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - loss: 0.3631 - precision_1: 0.2710 - recall_1: 0.2875 - val_loss: 0.2575 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3454 - precision_1: 0.2951 - recall_1: 0.2646
# Epoch 6: val_loss improved from 0.25748 to 0.25058, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.3453 - precision_1: 0.2952 - recall_1: 0.2647 - val_loss: 0.2506 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3300 - precision_1: 0.3255 - recall_1: 0.2676
# Epoch 7: val_loss improved from 0.25058 to 0.24667, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - loss: 0.3300 - precision_1: 0.3255 - recall_1: 0.2675 - val_loss: 0.2467 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3199 - precision_1: 0.3505 - recall_1: 0.2587
# Epoch 8: val_loss improved from 0.24667 to 0.24469, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - loss: 0.3199 - precision_1: 0.3505 - recall_1: 0.2586 - val_loss: 0.2447 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3103 - precision_1: 0.3622 - recall_1: 0.2538
# Epoch 9: val_loss improved from 0.24469 to 0.24164, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - loss: 0.3103 - precision_1: 0.3622 - recall_1: 0.2537 - val_loss: 0.2416 - val_precision_1: 0.5344 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2998 - precision_1: 0.3976 - recall_1: 0.2488
# Epoch 10: val_loss improved from 0.24164 to 0.23942, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 0.2998 - precision_1: 0.3975 - recall_1: 0.2487 - val_loss: 0.2394 - val_precision_1: 0.5357 - val_recall_1: 0.2232 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2917 - precision_1: 0.4191 - recall_1: 0.2509
# Epoch 11: val_loss improved from 0.23942 to 0.23622, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.2917 - precision_1: 0.4190 - recall_1: 0.2509 - val_loss: 0.2362 - val_precision_1: 0.5517 - val_recall_1: 0.2150 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2872 - precision_1: 0.4197 - recall_1: 0.2417
# Epoch 12: val_loss improved from 0.23622 to 0.23361, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - loss: 0.2872 - precision_1: 0.4197 - recall_1: 0.2417 - val_loss: 0.2336 - val_precision_1: 0.5841 - val_recall_1: 0.1915 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2808 - precision_1: 0.4444 - recall_1: 0.2536
# Epoch 13: val_loss improved from 0.23361 to 0.23109, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.2808 - precision_1: 0.4443 - recall_1: 0.2536 - val_loss: 0.2311 - val_precision_1: 0.6182 - val_recall_1: 0.1572 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2735 - precision_1: 0.4594 - recall_1: 0.2488
# Epoch 14: val_loss improved from 0.23109 to 0.22766, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - loss: 0.2735 - precision_1: 0.4595 - recall_1: 0.2488 - val_loss: 0.2277 - val_precision_1: 0.6215 - val_recall_1: 0.2001 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2694 - precision_1: 0.4761 - recall_1: 0.2650
# Epoch 15: val_loss improved from 0.22766 to 0.22585, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - loss: 0.2694 - precision_1: 0.4762 - recall_1: 0.2650 - val_loss: 0.2259 - val_precision_1: 0.6279 - val_recall_1: 0.2157 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2617 - precision_1: 0.4979 - recall_1: 0.2744
# Epoch 16: val_loss improved from 0.22585 to 0.22470, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.2617 - precision_1: 0.4979 - recall_1: 0.2743 - val_loss: 0.2247 - val_precision_1: 0.6149 - val_recall_1: 0.2378 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2588 - precision_1: 0.5021 - recall_1: 0.2817
# Epoch 17: val_loss did not improve from 0.22470
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.2588 - precision_1: 0.5021 - recall_1: 0.2817 - val_loss: 0.2250 - val_precision_1: 0.6115 - val_recall_1: 0.2490 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2533 - precision_1: 0.5224 - recall_1: 0.2872
# Epoch 18: val_loss improved from 0.22470 to 0.22321, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - loss: 0.2534 - precision_1: 0.5223 - recall_1: 0.2871 - val_loss: 0.2232 - val_precision_1: 0.6322 - val_recall_1: 0.2140 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2501 - precision_1: 0.5189 - recall_1: 0.2862
# Epoch 19: val_loss improved from 0.22321 to 0.22236, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.2501 - precision_1: 0.5189 - recall_1: 0.2861 - val_loss: 0.2224 - val_precision_1: 0.6287 - val_recall_1: 0.2242 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2468 - precision_1: 0.5260 - recall_1: 0.2938
# Epoch 20: val_loss improved from 0.22236 to 0.22216, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - loss: 0.2468 - precision_1: 0.5260 - recall_1: 0.2937 - val_loss: 0.2222 - val_precision_1: 0.6153 - val_recall_1: 0.2556 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

# Get metric names from cnn_history.history
metric_names = list(cnn_history.history.keys())

# Print all keys in the history dictionary for debugging
print("History dictionary keys:", cnn_history.history.keys())

# Remove 'loss' and 'val_loss' if they are present in the list
if 'loss' in metric_names:
    metric_names.remove('loss')
if 'val_loss' in metric_names:
    metric_names.remove('val_loss')

print(f"Metric names: {metric_names}")

# Plot Training and Validation Loss
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('CNN Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# First Metric Plot (e.g., Precision)
plt.subplot(1, 2, 2)
plt.plot(cnn_history.history[metric_names[0]], label='Training Precision')
plt.plot(cnn_history.history[metric_names[2]], label='Validation Precision')
plt.title('CNN Model Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Second Metric (e.g., Recall)
plt.figure(figsize=(6, 6))
plt.plot(cnn_history.history[metric_names[1]], label='Training Recall')
plt.plot(cnn_history.history[metric_names[3]], label='Validation Recall')
plt.title('CNN Model Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# History dictionary keys: dict_keys(['loss', 'precision', 'recall', 'val_loss', 'val_precision', 'val_recall', 'learning_rate'])
# Metric names: ['precision', 'recall', 'val_precision', 'val_recall', 'learning_rate']

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

# Get metric names from cnn_history.history
metric_names = list(lstm_history.history.keys())

# Print all keys in the history dictionary for debugging
print("History dictionary keys:", lstm_history.history.keys())

# Remove 'loss' and 'val_loss' if they are present in the list
if 'loss' in metric_names:
    metric_names.remove('loss')
if 'val_loss' in metric_names:
    metric_names.remove('val_loss')

print(f"Metric names: {metric_names}")

plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(lstm_history.history['loss'], label='Training Loss')
plt.plot(lstm_history.history['val_loss'], label='Validation Loss')
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Precision plot
plt.subplot(1, 2, 2)
plt.plot(lstm_history.history[metric_names[0]], label='Training Precision')
plt.plot(lstm_history.history[metric_names[2]], label='Validation Precision')
plt.title('LSTM Model Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Recall
plt.figure(figsize=(6, 6))
plt.plot(lstm_history.history[metric_names[1]], label='Training Recall')
plt.plot(lstm_history.history[metric_names[3]], label='Validation Recall')
plt.title('LSTM Model Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.show()
# Out:
# History dictionary keys: dict_keys(['loss', 'precision_1', 'recall_1', 'val_loss', 'val_precision_1', 'val_recall_1', 'learning_rate'])
# Metric names: ['precision_1', 'recall_1', 'val_precision_1', 'val_recall_1', 'learning_rate']

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

#Complete here
import random
cnn_model.load_weights(checkpoint_cnn_filepath)  # Load weights from checkpoint_cnn_filepath
lstm_model.load_weights(checkpoint_lstm_filepath)  # Load weights from checkpoint_lstm_filepath


# List of genres
genres = [
    "Action", "Adventure", "Animation", "Biography", "Comedy", "Crime", "Documentary", "Drama", "Family", "Fantasy",
    "History", "Horror", "Music", "Musical", "Mystery", "N/A", "News", "Reality-TV", "Romance", "Sci-Fi", "Short",
    "Sport", "Thriller", "War", "Western"
]

num_examples = 5  # Number of examples to select
example_indices = random.sample(range(len(img_locs_train[0])), num_examples)

example_posters = [img_locs_train[0][idx] for idx in example_indices]
example_overviews = [overviews_train[idx] for idx in example_indices]
example_ground_truth = [labels_train[idx] for idx in example_indices]

# Function to get top-3 predictions
def get_top_predictions(model, dataset, top_n=3):
    predictions = model.predict(dataset)  # Predict probabilities
    top_indices = predictions.argsort(axis=-1)[:, -top_n:][:, ::-1]  # Sort and get top-N indices
    top_genres = [[genres[idx] for idx in indices] for indices in top_indices]  # Map indices to genre names
    return top_genres

# Function to map ground truth binary labels to genre names
def map_ground_truth_labels(labels):
    return [[genres[i] for i, val in enumerate(label_list) if val == 1] for label_list in labels]



# Prepare datasets for predictions
# CNN requires posters
example_posters_ds = tf.data.Dataset.from_tensor_slices((example_posters, [0] * len(example_posters)))
example_posters_ds = example_posters_ds.map(parse_image).map(img_process).batch(1)

# LSTM requires text overviews
example_overviews_ds = tf.data.Dataset.from_tensor_slices((example_overviews, [0] * len(example_overviews)))
example_overviews_ds = example_overviews_ds.batch(1)

# Make predictions
cnn_predictions = get_top_predictions(cnn_model, example_posters_ds)
lstm_predictions = get_top_predictions(lstm_model, example_overviews_ds)

# Convert ground truth to genre names
example_ground_truth_names = map_ground_truth_labels(example_ground_truth)

# Visualize results
for i, idx in enumerate(example_indices):
    # Plot poster
    poster_image = plt.imread(example_posters[i])
    plt.imshow(poster_image)
    plt.title(f"Poster for Film {idx}")
    plt.axis('off')
    plt.show()

    # Print overview
    print(f"Overview for Film {idx}:\n{example_overviews[i]}")
    print("\nGround Truth Genres:", example_ground_truth_names[i])

    # Display predictions
    print("Top-3 CNN Predictions:", cnn_predictions[i])
    print("Top-3 LSTM Predictions:", lstm_predictions[i])
    print("-----")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Overview for Film 4308:
# A West Texas Deputy Sheriff is slowly unmasked as a psychotic killer.
#
# Ground Truth Genres: ['Crime', 'Drama', 'Thriller']
# Top-3 CNN Predictions: ['Drama', 'Action', 'Thriller']
# Top-3 LSTM Predictions: ['Drama', 'Action', 'Comedy']
# -----
# Overview for Film 4290:
# A duke dies and leaves the title and wealth to his adult son. But who's the real son: the found baby raised in USA or the abandoned baby raised by a Hindi family in London? Comedy follows.
#
# Ground Truth Genres: ['Comedy']
# Top-3 CNN Predictions: ['Comedy', 'Adventure', 'Drama']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Romance']
# -----
# Overview for Film 223:
# A Japanese-American fisherman is accused of killing his neighbor at sea. In the 1950s, race figures into the trial. So does reporter Ishmael.
#
# Ground Truth Genres: ['Drama', 'Mystery', 'Romance']
# Top-3 CNN Predictions: ['Drama', 'Comedy', 'Romance']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Action']
# -----
# Overview for Film 4417:
# The lead singer of an oldies group reminisces about the good ol' days and a potential comeback.
#
# Ground Truth Genres: ['Drama']
# Top-3 CNN Predictions: ['Drama', 'Crime', 'Comedy']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Romance']
# -----
# Overview for Film 2096:
# A teen faces her impending adulthood in the carefree sex and drug revolution years of the early 80's prior to fears of AIDS. She lives with her bitter, divorced mother and her sadistic kid ...
#
# Ground Truth Genres: ['Drama']
# Top-3 CNN Predictions: ['Drama', 'Comedy', 'Romance']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Romance']
# -----
